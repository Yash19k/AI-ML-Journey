# %% [markdown]
# List

# %%
List=[1,2,3,4,5,6,7,8]
print(List)
print(type(List))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]
# <class 'list'>

# %%
for i in List:
    print(i,end=" ")
# Out:
# 1 2 3 4 5 6 7 8

# %%
print(len(List))
print(f"max term:{max(List)},min term:{min(List)}")
# Out:
# 8
# max term:8,min term:1
